# %% [markdown]
# <a href="https://colab.research.google.com/github/HBaaa/myd2l/blob/master/3/3_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %% [markdown]
# ### 获取此文件位置
# 路径只能使用`/content`之后，但是时间文件位置是在`/content/drive/My Drive/Colab Notebooks`

# %%
os.getcwd()
# Out:
# '/content'

# %%
# %matplotlib inline
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import sys

# %%
torch.__version__
# Out:
# '1.4.0'

# %%
# 将默认数据格式改为float32
torch.set_default_tensor_type(torch.FloatTensor)

# %% [markdown]
# ### 读取数据集

# %% [markdown]
# #### 导入数据

# %%
train_data = pd.read_csv('/content/drive/Shared drives/a/house-prices/train.csv')

# %%
test_data = pd.read_csv('./drive/Shared drives/a/house-prices/test.csv')

# %%
train_data.shape
# Out:
# (1460, 81)

# %%
test_data.shape
# Out:
# (1459, 80)

# %% [markdown]
# #### 查看样本的前4个样本(第一个参数)，查看样本的前4个特征与最后3个特征（第2个参数）

# %%
train_data.iloc[0:4,[0,1,2,3,-3,-2,-1]]
# Out:
#    Id  MSSubClass MSZoning  LotFrontage SaleType SaleCondition  SalePrice
# 0   1          60       RL         65.0       WD        Normal     208500
# 1   2          20       RL         80.0       WD        Normal     181500
# 2   3          60       RL         68.0       WD        Normal     223500
# 3   4          70       RL         60.0       WD       Abnorml     140000

# %% [markdown]
# #### `pd.concat`是进行数据拼接
# #### 第一个参数是需要拼接的数据，需要用`()`或者`[]`将其放在一起
# #### 第二个参数是`axis`，0的话（默认）表示水平连接（row）也就是继续增加行，=1的话是垂直方向(column)连接，也就是行不变，增加列

# %%
all_features = pd.concat([train_data.iloc[:,1:-1],test_data.iloc[:,1:]])

# %%
all_features.shape
# Out:
# (2919, 79)

# %% [markdown]
# ### 预处理数据

# %%
numeric_features = all_features.dtypes[all_features.dtypes != 'object'].index

# %%
all_features[numeric_features] = all_features[numeric_features].apply(lambda x: (x-x.mean())/(x.std()))

# %%
all_features = all_features.fillna(0)

# %%
all_features
# Out:
#       MSSubClass MSZoning  LotFrontage  ...    YrSold SaleType SaleCondition
# 0       0.067320       RL    -0.184443  ...  0.157619       WD        Normal
# 1      -0.873466       RL     0.458096  ... -0.602858       WD        Normal
# 2       0.067320       RL    -0.055935  ...  0.157619       WD        Normal
# 3       0.302516       RL    -0.398622  ... -1.363335       WD       Abnorml
# 4       0.067320       RL     0.629439  ...  0.157619       WD        Normal
# ...          ...      ...          ...  ...       ...      ...           ...
# 1454    2.419286       RM    -2.069222  ... -1.363335       WD        Normal
# 1455    2.419286       RM    -2.069222  ... -1.363335       WD       Abnorml
# 1456   -0.873466       RL     3.884968  ... -1.363335       WD       Abnorml
# 1457    0.655311       RL    -0.312950  ... -1.363335       WD        Normal
# 1458    0.067320       RL     0.201080  ... -1.363335       WD        Normal
#
# [2919 rows x 79 columns]
